-- %% [markdown]
-- # Module 4, Lecture 4.3 CREATE TABLE
--
-- This practice session will give you the opportunity to create several tables in PostgreSQL. The first step will be to create the tables that will store the actual university data. The second step will be to create the tables that will house the relationships between the tables.

-- %% [markdown]
-- ## Use the below data to create the tables in the University database
--
-- ```
-- NOTE: Be sure to use the standards discussed in Lecture 4.1. Code cells have already been inserted after each table definition
-- ```

-- %% [markdown]
-- ## Create the main database tables

-- %% [markdown]
-- Step 1: Connect to the correct database.
--
-- - Select the PostgreSQL connection in the "Attach to" drop-down above
-- - Change the database on the current connect (localhost) to the university database

-- %% [markdown]
-- Step 2: Create the 'student' table using the following information:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Number<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 10 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Last Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 25 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student First Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 25 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student City<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 50 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student State<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>2-digit digraph<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Zip<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>5-digit zip code<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Birth Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>DATE<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Cannot be less than 16 years old<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Start Semester<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Start Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>DATE<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Currently Enrolled?<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Yes/No<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Currently Has Honors?<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Yes/No<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student GPA<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Number<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student Credit Hours<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Academic Level ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program_ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School_ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Degree_ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 3: Create the 'class' table using the following information:
--
--
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 50 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Code<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 4 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Number<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 3 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Status<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 20 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Size<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Meeting Days<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 10 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Professor<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 4: Create the 'faculty' table using the information below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Number<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 10 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>FacultyLast Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 25 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty First Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 25 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty City<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 50 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty State<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>2-digit digraph<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Zip<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>5-digit zip code<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Birth Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Start Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Active<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Boolean<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty Teaching Hours</b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School ID</b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program ID</b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 5: Create the 'term' table using the information below:
--
--
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term Number<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 15 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 6: Create the 'academic level' table using the information below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Academic Level<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Academic Level ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Academic Level Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 25 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 7: Create the 'program' table using the information below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 15 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Director ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 8: Create the 'school' table using the Information below.
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 50 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Director ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 9: Create the 'degree' table usinfg the information below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Degree<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Degree ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>NOT NULL, Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Degree Name<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 100 characters<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Degree Abbreviation<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>String of 5 character<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>School ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Program ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- ## Part B: Create the many-to-many tables

-- %% [markdown]
-- Step 1: Create the table to house the students and faculty in each term using the information below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Terms and People<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Student ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term Start Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date</b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term End Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date</b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>

-- %% [markdown]
-- Step 2: Creat the table to house the available courses each term using the infomration below:
--
-- <table class="MsoTableGrid" border="1" cellspacing="0" cellpadding="0"><tbody><tr><td width="623" colspan="3" valign="top" style="width: 467.5pt; border-width: 1pt; border-style: solid; border-color: windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Terms and Classes<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Term ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Faculty ID<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Integer<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Primary Key<o:p></o:p></b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class Start Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr><tr><td width="208" valign="top" style="width: 155.8pt; border-right: 1pt solid windowtext; border-bottom: 1pt solid windowtext; border-left: 1pt solid windowtext; border-top: none; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Class End Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>Date<o:p></o:p></b></p></td><td width="208" valign="top" style="width: 155.85pt; border-top: none; border-left-color: initial; border-bottom: 1pt solid windowtext; border-right: 1pt solid windowtext; padding: 0in 5.4pt;"><p class="MsoNormal" style="margin: 0in; font-size: 12pt; font-family: Calibri, sans-serif;"><b>&nbsp;</b></p></td></tr></tbody></table>
